# %% [markdown]
# ### Step 0: Import necesaary llibraries & Reading Data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use("ggplot")
# pd.set_option('max_columns', 500)

# %%
df = pd.read_csv(r"C:\Users\erpra\Documents\Python_EDA\EDA_Rolller_Coaster_Dataset\coaster_db.csv")

# %% [markdown]
# ### Step 1: Understanding Data
#
# * Dataframe shape
# * First & last few rows and columns
# * Data Types
# * Description of each columns

# %%
# shape
df.shape
# Out:
# (1087, 56)

# %%
# first 5 enteries in dataset
df.head(5)
# Out:
#                              coaster_name          Length             Speed  \
# 0                      Switchback Railway  600 ft (180 m)  6 mph (9.7 km/h)
# 1                       Flip Flap Railway             NaN               NaN
# 2  Switchback Railway (Euclid Beach Park)             NaN               NaN
# 3            Loop the Loop (Coney Island)             NaN               NaN
# 4            Loop the Loop (Young's Pier)             NaN               NaN
#
#                          Location   Status   Opening date   Type  \
# 0                    Coney Island  Removed  June 16, 1884   Wood
# 1                   Sea Lion Park  Removed           1895   Wood
# 2  Cleveland, Ohio, United States   Closed            NaN  Other
# 3                           Other  Removed           1901  Steel
# 4                           Other  Removed           1901  Steel
#
#              Manufacturer Height restriction        Model  ...  speed1  \
# ...

# %%
# Last 5 enteries in dataset
df.tail()
# Out:
#                         coaster_name                Length  \
# 1082         American Dreier Looping    3,444 ft (1,050 m)
# 1083       Pantheon (roller coaster)    3,328 ft (1,014 m)
# 1084       Tron Lightcycle Power Run  3,169.3 ft (966.0 m)
# 1085                         Tumbili        770 ft (230 m)
# 1086  Wonder Woman Flight of Courage    3,300 ft (1,000 m)
#
#                         Speed                    Location              Status  \
# 1082         53 mph (85 km/h)                       Other                 NaN
# 1083        73 mph (117 km/h)  Busch Gardens Williamsburg  Under construction
# 1084  59.3[1] mph (95.4 km/h)                       Other                 NaN
# 1085         34 mph (55 km/h)              Kings Dominion  Under construction
# 1086         58 mph (93 km/h)    Six Flags Magic Mountain  Under construction
#
#        Opening date                                  Type  \
# 1082            NaN                                 Steel
# ...

# %%
# all columns name
df.columns
# Out:
# Index(['coaster_name', 'Length', 'Speed', 'Location', 'Status', 'Opening date',
#        'Type', 'Manufacturer', 'Height restriction', 'Model', 'Height',
#        'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
#        'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
#        'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
#        'Track layout', 'Fastrack available', 'Soft opening date.1',
#        'Closing date', 'Opened', 'Replaced by', 'Website',
#        'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
#        'Single rider line available', 'Restraint Style',
#        'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
#        'year_introduced', 'latitude', 'longitude', 'Type_Main',
#        'opening_date_clean', 'speed1', 'speed2', 'speed1_value', 'speed1_unit',
#        'speed_mph', 'height_value', 'height_unit', 'height_ft',
#        'Inversions_clean', 'Gforce_clean'],
# ...

# %%
# checking data types (dtypes)
df.dtypes
# Out:
# coaster_name                      object
# Length                            object
# Speed                             object
# Location                          object
# Status                            object
# Opening date                      object
# Type                              object
# Manufacturer                      object
# Height restriction                object
# Model                             object
# Height                            object
# Inversions                       float64
# Lift/launch system                object
# Cost                              object
# Trains                            object
# Park section                      object
# Duration                          object
# Capacity                          object
# G-force                           object
# Designer                          object
# Max vertical angle                object
# Drop                              object
# Soft opening date                 object
# ...

# %%
# Statistical description of dataset
df.describe()
# Out:
#        Inversions  year_introduced    latitude   longitude  speed1_value  \
# count  932.000000      1087.000000  812.000000  812.000000    937.000000
# mean     1.547210      1994.986201   38.373484  -41.595373     53.850374
# std      2.114073        23.475248   15.516596   72.285227     23.385518
# min      0.000000      1884.000000  -48.261700 -123.035700      5.000000
# 25%      0.000000      1989.000000   35.031050  -84.552200     40.000000
# 50%      0.000000      2000.000000   40.289800  -76.653600     50.000000
# 75%      3.000000      2010.000000   44.799600    2.778100     63.000000
# max     14.000000      2022.000000   63.230900  153.426500    240.000000
#
#         speed_mph  height_value   height_ft  Inversions_clean  Gforce_clean
# count  937.000000    965.000000  171.000000       1087.000000    362.000000
# mean    48.617289     89.575171  101.996491          1.326587      3.824006
# std     16.678031    136.246444   67.329092          2.030854      0.989998
# ...

# %% [markdown]
# ### Step 2: Data Preperation
#
# * Dropping irrelevant columns
# * Identifying duplicate columns
# * Renaming Columns
# * Feature Creation
# * Feature Selection

# %%
# first way to filter the feature or create a subset of dataset
df = df[['coaster_name', 
       'Location',
       'Status',
       'Manufacturer', 
       'year_introduced', 
       'latitude', 
       'longitude', 'Type_Main',
       'opening_date_clean', 
       'speed_mph', 
        'height_ft',
       'Inversions_clean', 
       'Gforce_clean']].copy()

# second is by dropping the columns or feature
#  df.drop(['<Column_name>'], axis=1) # 1 for columns & 2 for row

# %%
df.head()
# Out:
#                              coaster_name                        Location  \
# 0                      Switchback Railway                    Coney Island
# 1                       Flip Flap Railway                   Sea Lion Park
# 2  Switchback Railway (Euclid Beach Park)  Cleveland, Ohio, United States
# 3            Loop the Loop (Coney Island)                           Other
# 4            Loop the Loop (Young's Pier)                           Other
#
#     Status            Manufacturer  year_introduced  latitude  longitude  \
# 0  Removed  LaMarcus Adna Thompson             1884   40.5740   -73.9780
# 1  Removed            Lina Beecher             1895   40.5780   -73.9790
# 2   Closed                     NaN             1896   41.5800   -81.5700
# 3  Removed          Edwin Prescott             1901   40.5745   -73.9780
# 4  Removed          Edwin Prescott             1901   39.3538   -74.4342
#
#   Type_Main opening_date_clean  speed_mph  height_ft  Inversions_clean  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1087 entries, 0 to 1086
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   coaster_name        1087 non-null   object
#  1   Location            1087 non-null   object
#  2   Status              874 non-null    object
#  3   Manufacturer        1028 non-null   object
#  4   year_introduced     1087 non-null   int64
#  5   latitude            812 non-null    float64
#  6   longitude           812 non-null    float64
#  7   Type_Main           1087 non-null   object
#  8   opening_date_clean  837 non-null    object
#  9   speed_mph           937 non-null    float64
#  10  height_ft           171 non-null    float64
#  11  Inversions_clean    1087 non-null   int64
#  12  Gforce_clean        362 non-null    float64
# dtypes: float64(5), int64(2), object(6)
# memory usage: 110.5+ KB

# %%
# changing the dtype
df['opening_date_clean'] = pd.to_datetime(df['opening_date_clean'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1087 entries, 0 to 1086
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   coaster_name        1087 non-null   object
#  1   Location            1087 non-null   object
#  2   Status              874 non-null    object
#  3   Manufacturer        1028 non-null   object
#  4   year_introduced     1087 non-null   int64
#  5   latitude            812 non-null    float64
#  6   longitude           812 non-null    float64
#  7   Type_Main           1087 non-null   object
#  8   opening_date_clean  837 non-null    datetime64[ns]
#  9   speed_mph           937 non-null    float64
#  10  height_ft           171 non-null    float64
#  11  Inversions_clean    1087 non-null   int64
#  12  Gforce_clean        362 non-null    float64
# dtypes: datetime64[ns](1), float64(5), int64(2), object(5)
# memory usage: 110.5+ KB

# %%
# Renaming the columns
df = df.rename(columns={'coaster_name':'Coaster_Name', 
                    'year_introduced':'Year_Introduced',
                    'opening_date_clean':'Opening_Date', 
                    'speed_mph':'Speed_mph',
                    'height_ft':'Height_ft', 
                    'Inversions_clean':'Inversions', 
                    'Gforce_clean':'Gforce'})

# %%
# Treating the missing or Null values
df.isna().sum()
# Out:
# Coaster_Name         0
# Location             0
# Status             213
# Manufacturer        59
# Year_Introduced      0
# latitude           275
# longitude          275
# Type_Main            0
# Opening_Date       250
# Speed_mph          150
# Height_ft          916
# Inversions           0
# Gforce             725
# dtype: int64

# %%
# Treating the duplicate values
df.loc[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Coaster_Name, Location, Status, Manufacturer, Year_Introduced, latitude, longitude, Type_Main, Opening_Date, Speed_mph, Height_ft, Inversions, Gforce]
# Index: []

# %%
# checking duplicate on subset of column
df.loc[df.duplicated(subset=['Coaster_Name'])].head()
# Out:
#                           Coaster_Name             Location     Status  \
# 43               Crystal Beach Cyclone   Crystal Beach Park    Removed
# 60                         Derby Racer         Revere Beach    Removed
# 61         Blue Streak (Conneaut Lake)   Conneaut Lake Park     Closed
# 167      Big Thunder Mountain Railroad                Other        NaN
# 237  Thunder Run (Canada's Wonderland)  Canada's Wonderland  Operating
#
#                                           Manufacturer  Year_Introduced  \
# 43                                  Traver Engineering             1927
# 60                                      Fred W. Pearce             1937
# 61                                                 NaN             1938
# 167  Arrow Development (California and Florida)Dyna...             1980
# 237                                         Mack Rides             1986
#
#      latitude  longitude Type_Main Opening_Date  Speed_mph  Height_ft  \
# ...

# %%
# checking an example of duplicate
df.query('Coaster_Name == "Crystal Beach Cyclone"')
# Out:
#              Coaster_Name            Location   Status        Manufacturer  \
# 39  Crystal Beach Cyclone  Crystal Beach Park  Removed  Traver Engineering
# 43  Crystal Beach Cyclone  Crystal Beach Park  Removed  Traver Engineering
#
#     Year_Introduced  latitude  longitude Type_Main Opening_Date  Speed_mph  \
# 39             1926   42.8617   -79.0598      Wood   1926-01-01       60.0
# 43             1927   42.8617   -79.0598      Wood   1926-01-01       60.0
#
#     Height_ft  Inversions  Gforce
# 39        NaN           0     4.0
# 43        NaN           0     4.0

# %%
df = df.loc[~df.duplicated(subset=['Coaster_Name', 'Location', 'Opening_Date'])] \
    .reset_index(drop=True).copy()
df.shape
# Out:
# (990, 13)

# %% [markdown]
# ### Step 3: Feature Understanding
#
# (Univariate Analysis)
#
# * Plotting Feature Distribution
# > * Histogram
# > * KDE
# > * Boxplot

# %%
df.Year_Introduced.value_counts()
# Out:
# Year_Introduced
# 1999    46
# 2000    45
# 1998    30
# 2001    29
# 2002    28
#         ..
# 1956     1
# 1959     1
# 1961     1
# 1895     1
# 1884     1
# Name: count, Length: 101, dtype: int64

# %%
# Bar Plot
ax = df['Year_Introduced'].value_counts() \
        .head(10) \
        .plot(kind='bar', title='Top 10 Years Roller Coaster Introduced', color='darkred', label=True)

ax.set_xlabel('Year Introduced')
ax.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
# Histogram
ax = df['Speed_mph'].plot(kind='hist',
                          bins=20, 
                          title='Coaster speed (mph)', color= 'g')

ax.set_xlabel('Speed (mph)')
# Out:
# Text(0.5, 0, 'Speed (mph)')

# %%
# KDE - Kernel Density Plot
ax = df['Speed_mph'].plot(kind='kde', 
                          title='Coaster speed (mph)', color= 'r', style='*')

ax.set_xlabel('Speed (mph)')
# Out:
# Text(0.5, 0, 'Speed (mph)')

# %%
# Boxplot
ax = df['Speed_mph'].plot(kind='box', title='Coasters speed distribution (mph)', label="")

ax.set_xlabel('Speed (mph)')
ax.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ### Step 4: Feature Relationship
#
# > * Scatterplot
# > * Heatmap Correlation
# > * Pairplot
# > * Groupby comparision

# %%
# Scatter Plot (Speed Vs. Height)
df.plot(kind='scatter',
        x='Speed_mph',
        y='Height_ft',
        color='black',
        title='Coaster Speed Vs. Height',
        label='');

# %%
# Scatter Plot (Speed Vs. Height) with Seaborn

ax = sns.scatterplot(x='Speed_mph',
                    y='Height_ft',
                    hue= 'Year_Introduced',
                    data=df)

# %%
# Pairplot with multiple features comparision

sns.pairplot(df,
            vars=['Year_Introduced','Height_ft', 'Inversions', 'Gforce'],
            hue='Type_Main')
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Visualizing the correlation between numeric features

df_corr = df[['Year_Introduced','Speed_mph',
    'Height_ft', 'Inversions', 'Gforce']].dropna().corr()

# %%
sns.heatmap(df_corr, annot=True)
plt.show()

# %% [markdown]
# ### Step 5: Ask a Question about the data
# > * Try to answer a question you have about the data using a plot or statistic.
#
# *What are the locations with the fastest roller coasters (minimum of 10)?*

# %%
ax = df.query('Location != "Other"') \
    .groupby('Location')['Speed_mph'] \
    .agg(['mean','count']) \
    .query('count >= 10') \
    .sort_values('mean')['mean'] \
    .plot(kind='barh', figsize=(12, 5), title='Average Coast Speed by Location', color='brown')
ax.set_xlabel('Average Coaster Speed')
plt.show()
